# %%
# !pip install -r /content/drive/MyDrive/forex/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 116.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 15.6 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/forex/tests/test_pipeline.py
# Out:
# [PASS] synthetic data shapes
# [PASS] technical indicators
# config.json: 100% 758/758 [00:00<00:00, 6.46MB/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin: 100% 438M/438M [00:02<00:00, 168MB/s]
# Loading weights: 100% 201/201 [00:00<00:00, 39409.83it/s]
# tokenizer_config.json: 100% 252/252 [00:00<00:00, 1.86MB/s]
# model.safetensors:   0% 0.00/438M [00:00<?, ?B/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 18.7MB/s]
# model.safetensors:   0% 0.00/438M [00:00<?, ?B/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 761kB/s]
# model.safetensors:   0% 0.00/438M [00:00<?, ?B/s]    sentiment backend in use: finbert
# model.safetensors: 100% 438M/438M [00:05<00:00, 86.5MB/s]
# [PASS] sentiment pipeline
# Loading weights: 100% 201/201 [00:00<00:00, 24499.58it/s]
# [PASS] fx panel + windowing (train=150, val=44, test=34)
# ...

# %%
# !python /content/drive/MyDrive/forex/main.py --pair XAU/USD --epochs 15
# Out:
# === Building multi-modal panel for XAU/USD (1500 sessions) ===
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 201/201 [00:00<00:00, 42233.00it/s]
# train=990  val=224  test=214  features=22
#
# === Training Hybrid CNN-LSTM-Transformer (proposed model) ===
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Hybrid model parameters: 4,001,059 (4.00M)
# epoch 01/15 | train_loss=0.006210 | val_loss=0.001017 | 15.4s
# epoch 02/15 | train_loss=0.001453 | val_loss=0.001043 | 14.3s
# epoch 03/15 | train_loss=0.001324 | val_loss=0.001016 | 14.3s
# epoch 04/15 | train_loss=0.001274 | val_loss=0.000982 | 14.5s
# epoch 05/15 | train_loss=0.001196 | val_loss=0.001123 | 14.5s
# ...
